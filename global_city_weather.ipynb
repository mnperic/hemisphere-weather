# %%
# Import dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
import scipy.stats as st
from scipy.stats import linregress

# Import API key
from api_keys import weather_api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %%
# Generate cities list

# List for holding lat/lng and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 614

# %%
# Hit API to call a weather check on each city

# Set base url and units variables, combine to define query url
url = "http://api.openweathermap.org/data/2.5/weather?"
units = "metric"
query_url = f"{url}appid={weather_api_key}&units={units}&q="

# Define empty lists to store data for each field
city_id_list = []
city_name_list = []
country_list = []
lng_list = []
lat_list = []
temp_list = []
humidity_list = []
clouds_list = []
wind_speed_list = []

# Loop through cities
for city in cities:
    
    # Get JSON response from the OpenWeather API
    response_json = requests.get(query_url + city).json()
    
    # Start the error handling
    # Retrieve the items for each field and append them to the empty lists  
    try:
        
        city_id = response_json['id']
        city_id_list.append(city_id)
            
        city_name = response_json['name']
        city_name_list.append(city_name)
        
        country_name = response_json['sys']['country']
        country_list.append(country_name)

        lng = response_json['coord']['lon']
        lng_list.append(lng)

        lat = response_json['coord']['lat']
        lat_list.append(lat)

        temp = response_json['main']['temp']
        temp_list.append(temp)

        humidity = response_json['main']['humidity']
        humidity_list.append(humidity)

        clouds = response_json['clouds']['all']
        clouds_list.append(clouds)

        wind_speed = response_json['wind']['speed']
        wind_speed_list.append(wind_speed)
    
        print(f"City Name: {city}, City ID: {city_id}")
    
    # Print error message and move on to the next city if there is an error
    except:
        
        print("That record does not exist, searching for next record...")
# Out:
# City Name: khatanga, City ID: 2022572
# City Name: saskylakh, City ID: 2017155
# City Name: bredasdorp, City ID: 1015776
# City Name: abha, City ID: 110690
# City Name: katsuura, City ID: 2112309
# City Name: upernavik, City ID: 3418910
# City Name: valley station, City ID: 4311963
# City Name: tiksi, City ID: 2015306
# City Name: iqaluit, City ID: 5983720
# City Name: nantucket, City ID: 4944903
# City Name: lakes entrance, City ID: 2160735
# City Name: punta arenas, City ID: 3874787
# City Name: ancud, City ID: 3899695
# City Name: mataura, City ID: 6201424
# City Name: ushuaia, City ID: 3833367
# City Name: hobart, City ID: 2163355
# City Name: kodiak, City ID: 5866583
# City Name: kaeo, City ID: 2189343
# City Name: barra do corda, City ID: 3406318
# City Name: lebu, City ID: 3883457
# City Name: bathsheba, City ID: 3374083
# That record does not exist, searching for next record...
# City Name: jamestown, City ID: 5122534
# City Name: clyde river, City ID: 5924351
# City Name: navahrudak, City ID: 624785
# City Name: presidencia roque saenz pena, City ID: 3840300
# That record does not exist, searching for next record...
# City Name: leningradskiy, City ID: 2123814
# City Name: atuona, City ID: 4020109
# City Name: rabo de peixe, City ID: 3372745
# City Name: myanaung, City ID: 1308204
# City Name: narsaq, City ID: 3421719
# City Name: barrow, City ID: 5880054
# City Name: floro, City ID: 3156980
# That record does not exist, searching for next record...
# City Name: busselton, City ID: 2075265
# City Name: nyurba, City ID: 2018735
# City Name: albany, City ID: 5106841
# City Name: fort nelson, City ID: 5955902
# City Name: loubomo, City ID: 2258261
# City Name: fortuna, City ID: 5563839
# City Name: kinel-cherkassy, City ID: 548622
# City Name: san andres, City ID: 3670218
# City Name: lubbock, City ID: 5525584
# City Name: yagodnoye, City ID: 2119626
# City Name: fukue, City ID: 1863997
# City Name: rikitea, City ID: 4030556
# City Name: palembang, City ID: 1633070
# City Name: sola, City ID: 2134814
# That record does not exist, searching for next record...
# City Name: honiara, City ID: 2108502
# City Name: bluff, City ID: 2206939
# City Name: biak, City ID: 1637001
# City Name: chepareria, City ID: 199604
# City Name: campo maior, City ID: 3403566
# City Name: avarua, City ID: 4035715
# City Name: lompoc, City ID: 5367788
# City Name: maragogi, City ID: 3395458
# City Name: port lincoln, City ID: 2063036
# City Name: tasiilaq, City ID: 3424607
# City Name: sitka, City ID: 5557293
# City Name: wangqing, City ID: 2034221
# City Name: geraldton, City ID: 2070998
# City Name: alofi, City ID: 4036284
# City Name: pauini, City ID: 3662927
# City Name: esperance, City ID: 2071860
# City Name: salalah, City ID: 286621
# City Name: nizwa, City ID: 286987
# City Name: laramie, City ID: 5830062
# City Name: cap malheureux, City ID: 934649
# City Name: ranau, City ID: 1733502
# City Name: saint-philippe, City ID: 935215
# City Name: broken hill, City ID: 2173911
# City Name: gazli, City ID: 1513990
# City Name: les cayes, City ID: 3728097
# City Name: cabo san lucas, City ID: 3985710
# City Name: kapaa, City ID: 5848280
# City Name: viisoara, City ID: 662920
# City Name: goderich, City ID: 5962442
# City Name: qaanaaq, City ID: 3831208
# That record does not exist, searching for next record...
# City Name: butaritari, City ID: 2110227
# That record does not exist, searching for next record...
# City Name: krasnyy chikoy, City ID: 2012349
# City Name: isangel, City ID: 2136825
# City Name: castro, City ID: 3466704
# City Name: pevek, City ID: 2122090
# City Name: nurota, City ID: 1513087
# City Name: kodinar, City ID: 1266397
# City Name: zeya, City ID: 2012593
# City Name: bethel, City ID: 5282297
# City Name: opuwo, City ID: 3354077
# City Name: ciudad real, City ID: 2519401
# City Name: nuristan, City ID: 1444363
# City Name: coahuayana, City ID: 4013679
# City Name: atlantic city, City ID: 4500546
# City Name: avesta, City ID: 2724231
# That record does not exist, searching for next record...
# City Name: brooks, City ID: 5909514
# City Name: san bartolome, City ID: 2511440
# City Name: pajan, City ID: 3653609
# That record does not exist, searching for next record...
# City Name: mar del plata, City ID: 3430863
# City Name: lagoa, City ID: 3372964
# City Name: pierre, City ID: 5767918
# City Name: tazovskiy, City ID: 1489853
# City Name: saint george, City ID: 5546220
# City Name: waddan, City ID: 2209055
# City Name: luderitz, City ID: 3355672
# City Name: port blair, City ID: 1259385
# City Name: ilulissat, City ID: 3423146
# City Name: giddalur, City ID: 1271213
# City Name: vaini, City ID: 4032243
# City Name: opochka, City ID: 515155
# City Name: necochea, City ID: 3430443
# City Name: mambajao, City ID: 1702348
# City Name: saint-pierre, City ID: 935214
# City Name: longyearbyen, City ID: 2729907
# City Name: sao filipe, City ID: 3374210
# City Name: paracuru, City ID: 3393115
# City Name: puerto ayora, City ID: 3652764
# City Name: victoria, City ID: 1819729
# City Name: hermanus, City ID: 3366880
# City Name: arraial do cabo, City ID: 3471451
# City Name: haines junction, City ID: 5969025
# City Name: atar, City ID: 2381334
# City Name: mahebourg, City ID: 934322
# City Name: yambio, City ID: 363656
# City Name: hithadhoo, City ID: 1282256
# City Name: mnogovershinnyy, City ID: 2019935
# City Name: nikolskoye, City ID: 546105
# City Name: caborca, City ID: 3996893
# City Name: general pico, City ID: 3855075
# City Name: carnarvon, City ID: 2074865
# City Name: iralaya, City ID: 3608828
# City Name: yulara, City ID: 6355222
# City Name: novoagansk, City ID: 1497210
# City Name: abu samrah, City ID: 172515
# City Name: saint anthony, City ID: 5044290
# City Name: severo-kurilsk, City ID: 2121385
# City Name: faya, City ID: 110690
# City Name: ayagoz, City ID: 1525988
# City Name: gayeri, City ID: 2360541
# City Name: sinegorye, City ID: 2121197
# City Name: sur, City ID: 286245
# City Name: primo tapia, City ID: 3979430
# City Name: dehloran, City ID: 136702
# City Name: bengkulu, City ID: 1649150
# That record does not exist, searching for next record...
# City Name: sainte-marie, City ID: 935255
# City Name: wenling, City ID: 1791464
# City Name: puerto del rosario, City ID: 2512186
# City Name: bac lieu, City ID: 1591474
# City Name: hilo, City ID: 5855927
# City Name: cape town, City ID: 3369157
# City Name: kavieng, City ID: 2094342
# City Name: noshiro, City ID: 2128867
# City Name: bandarbeyla, City ID: 64814
# City Name: bonthe, City ID: 2409914
# City Name: nouadhibou, City ID: 2377457
# City Name: san juan bautista, City ID: 3929493
# City Name: rawson, City ID: 3839307
# City Name: brae, City ID: 2654970
# City Name: cockburn town, City ID: 3576994
# City Name: kasongo-lunda, City ID: 2315026
# City Name: port alfred, City ID: 964432
# City Name: mbekenyera, City ID: 878006
# City Name: ribeira grande, City ID: 3372707
# City Name: tabou, City ID: 2281120
# City Name: chokurdakh, City ID: 2126123
# That record does not exist, searching for next record...
# City Name: kaitangata, City ID: 2208248
# City Name: constitucion, City ID: 3893726
# That record does not exist, searching for next record...
# City Name: laguna, City ID: 5364271
# City Name: san jeronimo, City ID: 3929611
# City Name: kirakira, City ID: 2178753
# City Name: manacapuru, City ID: 3663529
# City Name: port elizabeth, City ID: 964420
# City Name: keffi, City ID: 2334652
# City Name: te anau, City ID: 2181625
# City Name: gushikawa, City ID: 1863495
# That record does not exist, searching for next record...
# City Name: itoman, City ID: 1861280
# City Name: praia, City ID: 3374333
# City Name: santa helena de goias, City ID: 3450206
# City Name: cidreira, City ID: 3466165
# That record does not exist, searching for next record...
# City Name: tuktoyaktuk, City ID: 6170031
# City Name: bambous virieux, City ID: 1106677
# City Name: marmora, City ID: 6535469
# City Name: mandera, City ID: 187896
# City Name: beringovskiy, City ID: 2126710
# City Name: mattru, City ID: 2409215
# City Name: poum, City ID: 2138555
# City Name: dabat, City ID: 340358
# City Name: carman, City ID: 5917275
# City Name: myitkyina, City ID: 1307741
# City Name: cabedelo, City ID: 3404558
# City Name: chiredzi, City ID: 893485
# City Name: louisville, City ID: 4299276
# That record does not exist, searching for next record...
# City Name: adre, City ID: 245669
# City Name: egvekinot, City ID: 4031742
# City Name: port augusta, City ID: 2063056
# City Name: puerto escondido, City ID: 3520994
# City Name: ust-kulom, City ID: 478050
# City Name: port hawkesbury, City ID: 6111867
# City Name: hohhot, City ID: 2036892
# City Name: semey, City ID: 1519422
# City Name: krasnoye, City ID: 704277
# City Name: enumclaw, City ID: 5793822
# City Name: hamilton, City ID: 4513583
# City Name: puerto leguizamo, City ID: 3671437
# City Name: jiexiu, City ID: 1805833
# City Name: redmond, City ID: 5808079
# City Name: pitimbu, City ID: 3391889
# That record does not exist, searching for next record...
# City Name: san patricio, City ID: 4726521
# City Name: campos belos, City ID: 3467687
# City Name: yaan, City ID: 2338660
# City Name: ouadda, City ID: 236901
# City Name: montefiascone, City ID: 3172931
# City Name: codrington, City ID: 2171099
# City Name: platonovka, City ID: 509104
# City Name: lyuban, City ID: 625721
# City Name: seoul, City ID: 1835848
# City Name: grindavik, City ID: 3416888
# City Name: yellowknife, City ID: 6185377
# City Name: kapuskasing, City ID: 5989403
# City Name: naze, City ID: 1855540
# City Name: porto nacional, City ID: 3452711
# City Name: kawit, City ID: 1709007
# City Name: huainan, City ID: 1807681
# City Name: talnakh, City ID: 1490256
# City Name: kahului, City ID: 5847411
# City Name: leh, City ID: 1264976
# City Name: xining, City ID: 1788852
# City Name: fram, City ID: 3438106
# City Name: mecca, City ID: 104515
# City Name: sol-iletsk, City ID: 491019
# City Name: olga, City ID: 2018553
# City Name: aguimes, City ID: 2522325
# City Name: dingle, City ID: 1714733
# City Name: camacha, City ID: 2270385
# City Name: kudahuvadhoo, City ID: 1337607
# City Name: nome, City ID: 5870133
# City Name: san quintin, City ID: 3984997
# City Name: dhidhdhoo, City ID: 1337612
# City Name: caravelas, City ID: 3466980
# City Name: faanui, City ID: 4034551
# City Name: skegness, City ID: 2637762
# City Name: kavaratti, City ID: 1267390
# City Name: ginda, City ID: 1253628
# City Name: ust-barguzin, City ID: 2013986
# City Name: bunog, City ID: 1722579
# City Name: marzuq, City ID: 72181
# City Name: vila velha, City ID: 3445026
# City Name: meulaboh, City ID: 1214488
# City Name: shurob, City ID: 1514831
# City Name: new norfolk, City ID: 2155415
# City Name: korhogo, City ID: 2286304
# City Name: yumen, City ID: 1528998
# City Name: launceston, City ID: 2160517
# City Name: luangwa, City ID: 909887
# City Name: sibolga, City ID: 1213855
# City Name: arman, City ID: 2127060
# City Name: east london, City ID: 1006984
# City Name: port hardy, City ID: 6111862
# City Name: chuy, City ID: 3443061
# City Name: makhalino, City ID: 532092
# City Name: yar-sale, City ID: 1486321
# City Name: bosaso, City ID: 64013
# City Name: sambava, City ID: 1056899
# City Name: morgan city, City ID: 4333811
# City Name: kampene, City ID: 214575
# That record does not exist, searching for next record...
# City Name: goundam, City ID: 2456917
# City Name: bradley, City ID: 4608185
# City Name: zambezi, City ID: 895953
# City Name: zhezkazgan, City ID: 1516589
# City Name: santona, City ID: 3109527
# City Name: vestmannaeyjar, City ID: 3412093
# City Name: talavera, City ID: 1684019
# City Name: rae bareli, City ID: 1259064
# City Name: mwinilunga, City ID: 902620
# City Name: norden, City ID: 2862118
# City Name: georgetown, City ID: 1735106
# City Name: harper, City ID: 2276492
# City Name: norman wells, City ID: 6089245
# City Name: araouane, City ID: 2460954
# City Name: dawei, City ID: 1293625
# City Name: moron, City ID: 3430545
# That record does not exist, searching for next record...
# City Name: cimarron hills, City ID: 5417041
# City Name: shenjiamen, City ID: 1795632
# City Name: moerai, City ID: 4034188
# City Name: tuatapere, City ID: 2180815
# City Name: pingyin, City ID: 1798632
# City Name: ilam, City ID: 1283334
# City Name: baykit, City ID: 1510689
# City Name: kara-tyube, City ID: 797725
# City Name: santa maria, City ID: 3450083
# City Name: namatanai, City ID: 2090021
# City Name: hasaki, City ID: 2112802
# City Name: champerico, City ID: 3598787
# City Name: la ciotat, City ID: 3010025
# City Name: saint-georges, City ID: 3579925
# City Name: provideniya, City ID: 4031574
# City Name: plouzane, City ID: 2986626
# City Name: devrek, City ID: 748167
# City Name: walvis bay, City ID: 3359638
# City Name: margate, City ID: 2643044
# City Name: hovd, City ID: 1516048
# City Name: watertown, City ID: 4954611
# City Name: amga, City ID: 2027786
# City Name: karasjok, City ID: 779350
# City Name: cabrobo, City ID: 3404513
# City Name: half moon bay, City ID: 5354943
# City Name: houma, City ID: 4328010
# City Name: airai, City ID: 1651810
# City Name: hervey bay, City ID: 2146219
# City Name: derzhavinsk, City ID: 1524606
# City Name: bidar, City ID: 1275738
# City Name: manaure, City ID: 3675504
# City Name: dunedin, City ID: 2191562
# City Name: saldanha, City ID: 3361934
# City Name: beruwala, City ID: 1249931
# City Name: kedgwick, City ID: 6942800
# City Name: linhares, City ID: 3458498
# City Name: jinchang, City ID: 1805733
# That record does not exist, searching for next record...
# City Name: manoel urbano, City ID: 3663495
# City Name: bonfim, City ID: 3405215
# City Name: attock, City ID: 1184249
# City Name: dongsheng, City ID: 1812256
# City Name: nampula, City ID: 1033356
# City Name: ponta do sol, City ID: 2264557
# City Name: acapulco, City ID: 3533462
# City Name: nanortalik, City ID: 3421765
# City Name: mitsamiouli, City ID: 921786
# City Name: padang, City ID: 1633419
# City Name: souillac, City ID: 933995
# City Name: thompson, City ID: 6165406
# City Name: bilma, City ID: 2446796
# City Name: coria, City ID: 2519234
# City Name: pedernales, City ID: 3495137
# City Name: pangnirtung, City ID: 6096551
# City Name: aklavik, City ID: 5882953
# City Name: lokosovo, City ID: 1500399
# City Name: machinga, City ID: 927643
# City Name: praia da vitoria, City ID: 3372760
# City Name: klyuchevskiy, City ID: 2021980
# City Name: koumac, City ID: 2140558
# City Name: mbandaka, City ID: 2312895
# City Name: kruisfontein, City ID: 986717
# City Name: srednekolymsk, City ID: 2121025
# City Name: guerrero negro, City ID: 4021858
# City Name: russell, City ID: 4047434
# City Name: torbay, City ID: 6167817
# City Name: zyryanka, City ID: 2119283
# City Name: nalut, City ID: 2214432
# City Name: wattegama, City ID: 1224061
# City Name: cheremshan, City ID: 569318
# City Name: sisimiut, City ID: 3419842
# City Name: lorengau, City ID: 2092164
# City Name: villagarzon, City ID: 3665992
# City Name: dimona, City ID: 295328
# City Name: palu, City ID: 1633034
# City Name: almazar, City ID: 1512342
# City Name: gorontalo, City ID: 1643837
# City Name: gisborne, City ID: 2206854
# City Name: tucurui, City ID: 3385935
# City Name: ostrovnoy, City ID: 556268
# City Name: boende, City ID: 218680
# City Name: maumere, City ID: 1635815
# City Name: oussouye, City ID: 2246901
# City Name: jieshi, City ID: 1805857
# City Name: bennettsville, City ID: 4570634
# City Name: yasinya, City ID: 688365
# City Name: parakou, City ID: 2392204
# That record does not exist, searching for next record...
# City Name: ahipara, City ID: 2194098
# City Name: poli, City ID: 150689
# City Name: batemans bay, City ID: 2176639
# City Name: iwaki, City ID: 2112539
# City Name: shingu, City ID: 1847947
# City Name: medvedok, City ID: 527979
# City Name: aktau, City ID: 610612
# That record does not exist, searching for next record...
# City Name: itarema, City ID: 3393692
# City Name: shubarshi, City ID: 608270
# City Name: tilichiki, City ID: 2120591
# City Name: jinxiang, City ID: 1805334
# City Name: whitehaven, City ID: 2634096
# That record does not exist, searching for next record...
# City Name: u thong, City ID: 1149964
# City Name: mount hagen, City ID: 2090409
# City Name: hagenow, City ID: 2912481
# That record does not exist, searching for next record...
# That record does not exist, searching for next record...
# That record does not exist, searching for next record...
# City Name: arica, City ID: 3899361
# City Name: kontagora, City ID: 2334008
# City Name: san cristobal, City ID: 3628473
# City Name: aranos, City ID: 3358666
# City Name: sept-iles, City ID: 6144312
# City Name: karla, City ID: 590447
# City Name: abnub, City ID: 362973
# City Name: conceicao do araguaia, City ID: 3401845
# City Name: el tigre, City ID: 3641351
# City Name: okha, City ID: 2122614
# City Name: paamiut, City ID: 3421193
# City Name: korla, City ID: 1529376
# City Name: gold coast, City ID: 2165087
# City Name: boundiali, City ID: 2290836
# City Name: westport, City ID: 4845585
# City Name: pisco, City ID: 3932145
# City Name: udarnyy, City ID: 826996
# City Name: nuevo laredo, City ID: 3522551
# City Name: lewiston, City ID: 4969398
# City Name: zhigansk, City ID: 2012530
# City Name: muhos, City ID: 645765
# City Name: bursa, City ID: 750268
# City Name: nioki, City ID: 2311968
# City Name: neyshabur, City ID: 122285
# City Name: isla del bosque, City ID: 3976232
# City Name: ayutla, City ID: 4017924
# City Name: nunkini, City ID: 3522514
# City Name: ketchikan, City ID: 5554428
# City Name: bara, City ID: 2347758
# City Name: mayumba, City ID: 2399001
# City Name: ulladulla, City ID: 2145554
# City Name: gemena, City ID: 2315728
# City Name: vao, City ID: 2137773
# That record does not exist, searching for next record...
# City Name: toktogul, City ID: 1538648
# That record does not exist, searching for next record...
# City Name: marawi, City ID: 1701054
# City Name: kindu, City ID: 212902
# City Name: komsomolskiy, City ID: 1513491
# City Name: visnes, City ID: 3131500
# City Name: talas, City ID: 299900
# City Name: samoded, City ID: 499025
# City Name: briancon, City ID: 3030142
# City Name: pochutla, City ID: 3517970
# City Name: sri aman, City ID: 1735799
# City Name: namibe, City ID: 3347019
# City Name: tukrah, City ID: 88834
# City Name: vostok, City ID: 2013279
# City Name: chapleau, City ID: 5919915
# City Name: trairi, City ID: 3386177
# City Name: vestmanna, City ID: 2610343
# City Name: hay river, City ID: 5972762
# City Name: balabac, City ID: 1728675
# City Name: podor, City ID: 2245170
# City Name: azul, City ID: 3436199
# City Name: rudnogorsk, City ID: 2017378
# City Name: gejiu, City ID: 1810240
# City Name: tual, City ID: 1623197
# City Name: cartagena del chaira, City ID: 3792382
# City Name: mama, City ID: 2020313
# City Name: nantong, City ID: 1799722
# City Name: savannakhet, City ID: 1653316
# City Name: kajaani, City ID: 654899
# City Name: kailua, City ID: 5847486
# City Name: ilebo, City ID: 215976
# That record does not exist, searching for next record...
# City Name: liuzhou, City ID: 1803300
# City Name: ndele, City ID: 237379
# City Name: chapais, City ID: 5919850
# City Name: yatou, City ID: 1786855
# City Name: aykhal, City ID: 2027296
# City Name: kurayoshi, City ID: 1858301
# City Name: terney, City ID: 2015352
# City Name: shebunino, City ID: 2121324
# City Name: khilok, City ID: 2022463
# City Name: yerbogachen, City ID: 2012956
# City Name: stornoway, City ID: 2636790
# City Name: tommot, City ID: 2015179
# City Name: roswell, City ID: 4219934
# City Name: imbituba, City ID: 3461370
# City Name: leua, City ID: 3059101
# City Name: deputatskiy, City ID: 2028164
# City Name: virginia beach, City ID: 4791259
# City Name: siguiri, City ID: 2415702
# City Name: olafsvik, City ID: 3414079
# City Name: bubaque, City ID: 2374583
# City Name: chimbote, City ID: 3698304
# City Name: kristiansund, City ID: 6453331
# City Name: puruandiro, City ID: 3991219
# City Name: dumas, City ID: 5520552
# City Name: oromocto, City ID: 6094407
# City Name: coquimbo, City ID: 3893629
# City Name: urumqi, City ID: 1529102
# City Name: yozgat, City ID: 296560
# City Name: beaverlodge, City ID: 5896969
# City Name: atbasar, City ID: 1526038
# City Name: santa cruz, City ID: 3904906
# City Name: dikson, City ID: 1507390
# City Name: porbandar, City ID: 1259395
# City Name: harlingen, City ID: 4696233
# City Name: axim, City ID: 2303611
# City Name: shanhetun, City ID: 2034995
# City Name: carutapera, City ID: 3402648
# City Name: castleisland, City ID: 2965604
# City Name: liku, City ID: 1633034
# That record does not exist, searching for next record...
# City Name: suksun, City ID: 486413
# City Name: cherskiy, City ID: 2126199
# City Name: biu, City ID: 2346995
# City Name: hambantota, City ID: 1244926
# City Name: lokoja, City ID: 2331939
# City Name: pechory, City ID: 511785
# City Name: ninghai, City ID: 1799384
# City Name: okhotsk, City ID: 2122605
# City Name: abbeville, City ID: 3038789
# City Name: tokonou, City ID: 2414659
# City Name: katobu, City ID: 1640972
# City Name: brainerd, City ID: 5019116
# City Name: teya, City ID: 1489656
# City Name: bayanday, City ID: 2027004
# City Name: san carlos de bariloche, City ID: 7647007
# City Name: antofagasta, City ID: 3899539
# City Name: ambunti, City ID: 2100933
# City Name: cayenne, City ID: 3382160
# City Name: ponta delgada, City ID: 3372783
# City Name: klaksvik, City ID: 2618795
# City Name: matagami, City ID: 6067747
# City Name: makakilo city, City ID: 5850554
# City Name: lena, City ID: 3118547
# City Name: husavik, City ID: 2629833
# City Name: kirkenaer, City ID: 3150261
# City Name: general roca, City ID: 3855065
# City Name: moranbah, City ID: 6533368
# City Name: namtsy, City ID: 2019488
# City Name: grand gaube, City ID: 934479
# City Name: ormara, City ID: 1168700
# City Name: galesong, City ID: 1644605
# City Name: lata, City ID: 2738381
# That record does not exist, searching for next record...
# City Name: lima, City ID: 3936456
# City Name: college, City ID: 5859699
# City Name: shihezi, City ID: 1529195
# City Name: rauma, City ID: 639734
# City Name: riachao do jacuipe, City ID: 3451474
# That record does not exist, searching for next record...
# City Name: cedral, City ID: 4014914
# City Name: verkhnyaya inta, City ID: 1487332
# City Name: batagay, City ID: 2027044
# City Name: coihaique, City ID: 3894426
# City Name: pacifica, City ID: 5380420
# City Name: cascais, City ID: 2269594
# City Name: nizhnyaya omka, City ID: 1497406
# City Name: dapaong, City ID: 2367164
# City Name: gizo, City ID: 2108857
# City Name: vila franca do campo, City ID: 3372472
# City Name: limbe, City ID: 2229411
# City Name: moose factory, City ID: 6078372
# City Name: hualmay, City ID: 3939761
# City Name: mehamn, City ID: 778707
# That record does not exist, searching for next record...
# City Name: la palma, City ID: 5364022
# City Name: garbolovo, City ID: 561999
# City Name: dalvik, City ID: 2632287
# City Name: nago, City ID: 1856068
# City Name: upington, City ID: 945945
# City Name: porto novo, City ID: 2392087
# City Name: alice springs, City ID: 2077895
# City Name: sakakah, City ID: 102527
# That record does not exist, searching for next record...
# City Name: kloulklubed, City ID: 7671223
# City Name: buala, City ID: 2109528
# City Name: teguldet, City ID: 1489822
# City Name: tura, City ID: 1254046
# City Name: caceres, City ID: 2520610
# City Name: sioux lookout, City ID: 6148373
# City Name: puquio, City ID: 3931223
# City Name: severodvinsk, City ID: 496285
# City Name: duliagaon, City ID: 1272259
# That record does not exist, searching for next record...
# City Name: pangai, City ID: 4032369
# That record does not exist, searching for next record...
# City Name: vardo, City ID: 777019
# City Name: hofn, City ID: 2630299
# City Name: waipawa, City ID: 2206874
# City Name: malanje, City ID: 2239862
# City Name: whitianga, City ID: 2179103
# That record does not exist, searching for next record...
# City Name: mananjary, City ID: 1061335
# City Name: ulaangom, City ID: 1515029
# City Name: manyana, City ID: 933416
# City Name: cornwall, City ID: 5928065
# City Name: svetlaya, City ID: 2015852
# That record does not exist, searching for next record...
# City Name: lavrentiya, City ID: 4031637
# City Name: wagar, City ID: 364027
# City Name: shelburne, City ID: 6145890
# City Name: usinsk, City ID: 863061
# City Name: lazaro cardenas, City ID: 4026082
# City Name: boa vista, City ID: 3664980
# City Name: capaci, City ID: 2525392
# City Name: tuensang, City ID: 1254133
# City Name: djibo, City ID: 2361177
# City Name: montbeliard, City ID: 2992938
# City Name: la rioja, City ID: 3336897
# City Name: lerwick, City ID: 2644605
# City Name: jaguey grande, City ID: 3556437
# City Name: ballina, City ID: 2177069
# City Name: visby, City ID: 2662689
# City Name: bolu, City ID: 750510
# City Name: bud, City ID: 4255151
# City Name: grand-santi, City ID: 3381538
# City Name: wuwei, City ID: 1803936
# City Name: kununurra, City ID: 2068110
# City Name: bima, City ID: 1648759
# City Name: tonk, City ID: 1254241
# City Name: isabela, City ID: 1710519
# City Name: dakar, City ID: 2253354
# City Name: mastic beach, City ID: 5126209
# City Name: bassano, City ID: 5894642
# City Name: sao bento do sul, City ID: 3449350
# City Name: tacuarembo, City ID: 3440034
# City Name: la ronge, City ID: 6050066
# City Name: nagua, City ID: 3496021
# City Name: little current, City ID: 6055388
# City Name: nanakuli, City ID: 5851349
# City Name: mocuba, City ID: 1024312
# City Name: gunjur, City ID: 2413419
# City Name: luanda, City ID: 2240449
# City Name: robertson, City ID: 4653638
# City Name: annur, City ID: 1278539
# City Name: the valley, City ID: 3573374
# City Name: benguela, City ID: 3351663

# %%
# Convert data into dataframe
cities_df = pd.DataFrame({"City ID": city_id_list, "City": city_name_list, "Country": country_list, "Lat": lat_list, "Lng": lng_list,
                         "Temperature": temp_list, "Humidity": humidity_list, "Clouds": clouds_list,
                         "Wind Speed": wind_speed_list})
cities_df.head()
# Out:
#    City ID        City Country      Lat       Lng  Temperature  Humidity  \
# 0  2022572    Khatanga      RU  71.9667  102.5000        -6.02        91
# 1  2017155   Saskylakh      RU  71.9167  114.0833        -4.90        92
# 2  1015776  Bredasdorp      ZA -34.5322   20.0403        15.62        75
# 3   110690        Abhā      SA  18.2164   42.5053        20.14        46
# 4  2112309    Katsuura      JP  35.1333  140.3000        18.17        72
#
#    Clouds  Wind Speed
# 0      16        5.28
# 1     100        2.06
# 2     100        6.15
# 3       0        0.00
# 4     100        2.97

# %%
# Export to .csv file
cities_df.to_csv("/Users/minoperic/Data Analytics/Data Investigations/global-city-weather/Resources/city_weather.csv", index=False, header=True)

# %%
# Plot – Latitude vs. Temperature

# Font families
font_1 = {'family':'helvetica','color':'black','size':16}
font_2 = {'family':'helvetica','color':'black','size':12}

# Plot
x_values = cities_df["Lat"]
y_values = cities_df["Temperature"]
plt.scatter(x_values,y_values)

# Titles / labels
plt.title('Temperatures at Latitude Positions', fontdict = font_1)
plt.xlabel('Latitude', fontdict = font_2)
plt.ylabel('Temperature (C)', fontdict = font_2)

# Limit x/y axis
plt.ylim(0, 40)
plt.xlim(-80, 80)

# Ticks
plt.minorticks_on()

# Grid
plt.grid(which='major', linestyle='-')
plt.grid(which='minor', linestyle=':')

# Layout
plt.tight_layout()
plt.gca().spines['top'].set_visible(False)
plt.gca().spines['right'].set_visible(False)

# Show and save
plt.savefig("/Users/minoperic/Data Analytics/Data Investigations/global-city-weather/Images/lat_temp.png")
plt.show()

# %%
# Plot – Latitude vs. Humidity

# Font families
font_1 = {'family':'helvetica','color':'black','size':16}
font_2 = {'family':'helvetica','color':'black','size':12}

# Plot
x_values = cities_df["Lat"]
y_values = cities_df["Humidity"]
plt.scatter(x_values,y_values)

# Titles / labels
plt.title('Humidity at Latitude Positions', fontdict = font_1)
plt.xlabel('Latitude', fontdict = font_2)
plt.ylabel('Humidity (%)', fontdict = font_2)

# Limit x/y axis
plt.ylim(0, 105)
plt.xlim(-80, 80)

# Ticks
plt.minorticks_on()

# Grid
plt.grid(which='major', linestyle='-')
plt.grid(which='minor', linestyle=':')

# Layout
plt.tight_layout()
plt.gca().spines['top'].set_visible(False)
plt.gca().spines['right'].set_visible(False)

# Show and save
plt.savefig("/Users/minoperic/Data Analytics/Data Investigations/global-city-weather/Images/lat_humidity.png")
plt.show()

# %%
# Plot – Latitude vs. Cloudiness

# Font families
font_1 = {'family':'helvetica','color':'black','size':16}
font_2 = {'family':'helvetica','color':'black','size':12}

# Plot
x_values = cities_df["Lat"]
y_values = cities_df["Clouds"]
plt.scatter(x_values,y_values)

# Titles / labels
plt.title('Cloudiness at Latitude Positions', fontdict = font_1)
plt.xlabel('Latitude', fontdict = font_2)
plt.ylabel('Cloudiness (%)', fontdict = font_2)

# Limit x/y axis
plt.ylim(-5, 105)
plt.xlim(-80, 80)

# Ticks
plt.minorticks_on()

# Grid
plt.grid(which='major', linestyle='-')
plt.grid(which='minor', linestyle=':')

# Layout
plt.tight_layout()
plt.gca().spines['top'].set_visible(False)
plt.gca().spines['right'].set_visible(False)

# Show and save
plt.savefig("/Users/minoperic/Data Analytics/Data Investigations/global-city-weather/Images/lat_cloudiness.png")
plt.show()

# %%
# Plot – Latitude vs. Wind Speed

# Font families
font_1 = {'family':'helvetica','color':'black','size':16}
font_2 = {'family':'helvetica','color':'black','size':12}

# Plot
x_values = cities_df["Lat"]
y_values = cities_df["Wind Speed"]
plt.scatter(x_values,y_values)

# Titles / labels
plt.title('Wind Speeds at Latitude Positions', fontdict = font_1)
plt.xlabel('Latitude', fontdict = font_2)
plt.ylabel('Wind Speed (kph)', fontdict = font_2)

# Limit x/y axis
plt.ylim(0, 25)
plt.xlim(-80, 80)

# Ticks
plt.minorticks_on()

# Grid
plt.grid(which='major', linestyle='-')
plt.grid(which='minor', linestyle=':')

# Layout
plt.tight_layout()
plt.gca().spines['top'].set_visible(False)
plt.gca().spines['right'].set_visible(False)

# Show and save
plt.savefig("/Users/minoperic/Data Analytics/Data Investigations/global-city-weather/Images/lat_wind_speed.png")
plt.show()

# %%
# Linear regression

# Create a function to create linear regression plots
def linear_regression(x_values, y_values):
    (slope, intercept, rvalue, pvalue, stderr) = st.linregress(x_values, y_values)
    regress_values = x_values * slope + intercept
    line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
    correlation = st.pearsonr(x_values, y_values)
    
    print(f"r-squared: {rvalue**2}")
    print(f"Correlation: {correlation}")
    print(f"Line: {line_eq}")

    return regress_values, line_eq

# %%
# Create Northern/Southern hemisphere DataFrames
mask = cities_df['Lat'] > 0
northern_hemisphere = cities_df[mask]
southern_hemisphere = cities_df[~mask]

# %%
# Linear regression – Northern Hemisphere (max temp vs. latitude)

# Font families
font_1 = {'family':'helvetica','color':'black','size':16}
font_2 = {'family':'helvetica','color':'black','size':12}

# Plot
x_values = northern_hemisphere["Lat"]
y_values = northern_hemisphere["Temperature"]

# Linear regression
(slope, intercept, rvalue, pvalue, stderr) = st.linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
correlation = st.pearsonr(x_values, y_values)

# LR + plot / titles / labels
plt.scatter(x_values,y_values)
plt.title('Temperatures at Latitude Positions (Northern Hemisphere)', fontdict = font_1)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(50,20),fontsize=12,color="red")
plt.xlabel('Latitude', fontdict = font_2)
plt.ylabel('Temperature (C)', fontdict = font_2)

# Limit axis
plt.ylim(-50, 40)
plt.xlim(0, 80)

# Ticks
plt.minorticks_on()
plt.grid(which='major', linestyle='-')
plt.grid(which='minor', linestyle=':')

# Layout
plt.tight_layout()
plt.gca().spines['top'].set_visible(False)
plt.gca().spines['right'].set_visible(False)

# Show and save
plt.savefig("/Users/minoperic/Data Analytics/Data Investigations/global-city-weather/Images/nh_lat_temp_regression.png")
plt.show()

# %%
# Linear regression – Southern Hemisphere (max temp vs. latitude)

# Font families
font_1 = {'family':'helvetica','color':'black','size':16}
font_2 = {'family':'helvetica','color':'black','size':12}

# Plot 
x_values = southern_hemisphere["Lat"]
y_values = southern_hemisphere["Temperature"]

# LR + plot / titles / labels
(slope, intercept, rvalue, pvalue, stderr) = st.linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
correlation = st.pearsonr(x_values, y_values)
plt.scatter(x_values,y_values)

# Titles / labels / annotations
plt.title('Temperatures at Latitude Positions (Southern Hemisphere)', fontdict = font_1)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(-52,23),fontsize=12,color="red")
plt.xlabel('Latitude', fontdict = font_2)
plt.ylabel('Temperature (C)', fontdict = font_2)

# Limit axis
plt.ylim(5, 40)
plt.xlim(0, -60)

# Ticks
plt.minorticks_on()

# Layout
plt.grid(which='major', linestyle='-')
plt.grid(which='minor', linestyle=':')
plt.tight_layout()
plt.gca().spines['top'].set_visible(False)
plt.gca().spines['right'].set_visible(False)

# Show and save
plt.savefig("/Users/minoperic/Data Analytics/Data Investigations/global-city-weather/Images/sh_lat_temp_regression.png")
plt.show()

# %%
# Linear regression – Northern Hemisphere (Humidity vs. latitude)

# Font families
font_1 = {'family':'helvetica','color':'black','size':16}
font_2 = {'family':'helvetica','color':'black','size':12}

# Plot
x_values = northern_hemisphere["Lat"]
y_values = northern_hemisphere["Humidity"]

# LR + plot / titles / labels
(slope, intercept, rvalue, pvalue, stderr) = st.linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
correlation = st.pearsonr(x_values, y_values)

# Titles / labels / annotations
plt.scatter(x_values,y_values)
plt.title('Humidity at Latitude Positions (Northern Hemisphere)', fontdict = font_1)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(50,20), fontsize=12, color="red")
plt.xlabel('Latitude', fontdict = font_2)
plt.ylabel('Humidity (%)', fontdict = font_2)

# Limit axis
plt.ylim(0, 105)
plt.xlim(0, 80)

# Ticks
plt.minorticks_on()

# Layout
plt.grid(which='major', linestyle='-')
plt.grid(which='minor', linestyle=':')
plt.gca().spines['top'].set_visible(False)
plt.gca().spines['right'].set_visible(False)
plt.tight_layout()
plt.savefig("/Users/minoperic/Data Analytics/Data Investigations/global-city-weather/Images/nh_lat_humidity_regression.png")
plt.show()

# %%
# Linear regression – Southern Hemisphere (Humidity vs. latitude)

# Font families
font_1 = {'family':'helvetica','color':'black','size':16}
font_2 = {'family':'helvetica','color':'black','size':12}

# Plot
x_values = southern_hemisphere["Lat"]
y_values = southern_hemisphere["Humidity"]

# LR + plot / titles / labels
(slope, intercept, rvalue, pvalue, stderr) = st.linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
correlation = st.pearsonr(x_values, y_values)

# Titles / labels / annotations
plt.scatter(x_values,y_values)
plt.title('Humidity at Latitude Positions (Southern Hemisphere)', fontdict = font_1)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(-35,10),fontsize=12,color="red")
plt.xlabel('Latitude', fontdict = font_2)
plt.ylabel('Humidity (%)', fontdict = font_2)

# Limit axis
plt.ylim(0, 105)
plt.xlim(0, -60)

# Ticks
plt.minorticks_on()

# Layout
plt.grid(which='major', linestyle='-')
plt.grid(which='minor', linestyle=':')
plt.tight_layout()
plt.gca().spines['top'].set_visible(False)
plt.gca().spines['right'].set_visible(False)

# Show and save
plt.savefig("/Users/minoperic/Data Analytics/Data Investigations/global-city-weather/Images/sh_lat_humidity_regression.png")
plt.show()

# %%
# Linear regression – Northern Hemisphere (Cloudiness vs. latitude)

# Font families
font_1 = {'family':'helvetica','color':'black','size':16}
font_2 = {'family':'helvetica','color':'black','size':12}

# Plot
x_values = northern_hemisphere["Lat"]
y_values = northern_hemisphere["Clouds"]

# LR + plot / titles / labels
(slope, intercept, rvalue, pvalue, stderr) = st.linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
correlation = st.pearsonr(x_values, y_values)
plt.scatter(x_values,y_values)

# Titles / labels / annotations
plt.title('Cloudiness at Latitude Positions (Northern Hemisphere)', fontdict = font_1)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(55,50), fontsize=12, color="red")
plt.xlabel('Latitude', fontdict = font_2)
plt.ylabel('Cloudiness (%)', fontdict = font_2)

# Limit axis
plt.ylim(-5, 105)
plt.xlim(0, 80)

# Ticks
plt.minorticks_on()

# Layout
plt.grid(which='major', linestyle='-')
plt.grid(which='minor', linestyle=':')
plt.tight_layout()
plt.gca().spines['top'].set_visible(False)
plt.gca().spines['right'].set_visible(False)

# Save and show
plt.savefig("/Users/minoperic/Data Analytics/Data Investigations/global-city-weather/Images/nh_lat_cloud_regression.png")
plt.show()

# %%
# Linear regression – Southern Hemisphere (Cloudiness vs. latitude)

# Font families
font_1 = {'family':'helvetica','color':'black','size':16}
font_2 = {'family':'helvetica','color':'black','size':12}

# Plot
x_values = southern_hemisphere["Lat"]
y_values = southern_hemisphere["Clouds"]

# LR + plot / titles / labels
(slope, intercept, rvalue, pvalue, stderr) = st.linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
correlation = st.pearsonr(x_values, y_values)
plt.scatter(x_values,y_values)

# Titles / labels / annotations
plt.title('Cloudiness at Latitude Positions (Southern Hemisphere)', fontdict = font_1)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(-35,60),fontsize=12,color="red")
plt.xlabel('Latitude', fontdict = font_2)
plt.ylabel('Cloudiness (%)', fontdict = font_2)

# Limit axis
plt.ylim(-5, 105)
plt.xlim(0, -60)

# Ticks
plt.minorticks_on()

# Layout
plt.grid(which='major', linestyle='-')
plt.grid(which='minor', linestyle=':')
plt.gca().spines['top'].set_visible(False)
plt.gca().spines['right'].set_visible(False)
plt.tight_layout()

# Show and save
plt.savefig("/Users/minoperic/Data Analytics/Data Investigations/global-city-weather/Images/sh_lat_cloud_regression.png")
plt.show()

# %%
# Linear regression – Northern Hemisphere (Wind Speed vs. latitude)

# Font families
font_1 = {'family':'helvetica','color':'black','size':16}
font_2 = {'family':'helvetica','color':'black','size':12}

# Plot
x_values = northern_hemisphere["Lat"]
y_values = northern_hemisphere["Wind Speed"]

# LR + plot / titles / labels
(slope, intercept, rvalue, pvalue, stderr) = st.linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
correlation = st.pearsonr(x_values, y_values)
plt.scatter(x_values,y_values)

# Titles / labels / annotations
plt.title('Wind Speed at Latitude Positions (Northern Hemisphere)', fontdict = font_1)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(50,16),fontsize=12,color="red")
plt.xlabel('Latitude', fontdict = font_2)
plt.ylabel('Wind Speed (kph)', fontdict = font_2)

# Limit axis
plt.ylim(0, 30)
plt.xlim(0, 80)

# Ticks
plt.minorticks_on()

# Layout
plt.grid(which='major', linestyle='-')
plt.grid(which='minor', linestyle=':')
plt.tight_layout()
plt.gca().spines['top'].set_visible(False)
plt.gca().spines['right'].set_visible(False)

# Show and save
plt.savefig("/Users/minoperic/Data Analytics/Data Investigations/global-city-weather/Images/nh_lat_wind_regression.png")
plt.show()

# %%
# Linear regression – Southern Hemisphere (Wind Speed vs. latitude)

# Font families
font_1 = {'family':'helvetica','color':'black','size':16}
font_2 = {'family':'helvetica','color':'black','size':12}

# Plot
x_values = southern_hemisphere["Lat"]
y_values = southern_hemisphere["Wind Speed"]

# LR + plot / titles / labels
(slope, intercept, rvalue, pvalue, stderr) = st.linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
correlation = st.pearsonr(x_values, y_values)
plt.scatter(x_values,y_values)

# Titles / labels / annotations
plt.title('Wind Speed at Latitude Positions (Southern Hemisphere)', fontdict = font_1)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(-30,16),fontsize=12,color="red")
plt.xlabel('Latitude', fontdict = font_2)
plt.ylabel('Wind Speed (kph)', fontdict = font_2)

# Limit axis
plt.ylim(0, 20)
plt.xlim(0, -60)

# Ticks
plt.minorticks_on()

# Layout
plt.grid(which='major', linestyle='-')
plt.grid(which='minor', linestyle=':')
plt.tight_layout()
plt.gca().spines['top'].set_visible(False)
plt.gca().spines['right'].set_visible(False)

# Show and save
plt.savefig("/Users/minoperic/Data Analytics/Data Investigations/global-city-weather/Images/sh_lat_wind_regression.png")
plt.show()
